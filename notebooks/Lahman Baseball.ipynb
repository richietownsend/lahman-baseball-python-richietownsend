# %%
import pandas as pd
from sqlalchemy import create_engine
import re

# establish a database connection
engine = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5433/lahman_baseball")
# Replace `<lahman_baseball_database_name>` with the actual name of your lahman baseball database as it appears in pgadmin

# use the connection to run a query using pandas!
df = pd.read_sql("SELECT * FROM batting;", con=engine)
df.head()
# Out:
#     playerid  yearid  stint teamid lgid   g   ab   r   h  h2b  ...   rbi   sb  \
# 0  abercda01    1871      1    TRO   NA   1    4   0   0    0  ...   0.0  0.0
# 1   addybo01    1871      1    RC1   NA  25  118  30  32    6  ...  13.0  8.0
# 2  allisar01    1871      1    CL1   NA  29  137  28  40    4  ...  19.0  3.0
# 3  allisdo01    1871      1    WS3   NA  27  133  28  44   10  ...  27.0  1.0
# 4  ansonca01    1871      1    RC1   NA  25  120  29  39   11  ...  16.0  6.0
#
#     cs  bb   so  ibb  hbp  sh  sf  gidp
# 0  0.0   0  0.0  NaN  NaN NaN NaN   NaN
# 1  1.0   4  0.0  NaN  NaN NaN NaN   NaN
# 2  1.0   2  5.0  NaN  NaN NaN NaN   NaN
# 3  1.0   0  2.0  NaN  NaN NaN NaN   NaN
# 4  2.0   2  1.0  NaN  NaN NaN NaN   NaN
#
# [5 rows x 22 columns]

# %%
df = pd.read_sql("SELECT * FROM batting;", con=engine)
df.head()
# Out:
#     playerid  yearid  stint teamid lgid   g   ab   r   h  h2b  ...   rbi   sb  \
# 0  abercda01    1871      1    TRO   NA   1    4   0   0    0  ...   0.0  0.0
# 1   addybo01    1871      1    RC1   NA  25  118  30  32    6  ...  13.0  8.0
# 2  allisar01    1871      1    CL1   NA  29  137  28  40    4  ...  19.0  3.0
# 3  allisdo01    1871      1    WS3   NA  27  133  28  44   10  ...  27.0  1.0
# 4  ansonca01    1871      1    RC1   NA  25  120  29  39   11  ...  16.0  6.0
#
#     cs  bb   so  ibb  hbp  sh  sf  gidp
# 0  0.0   0  0.0  NaN  NaN NaN NaN   NaN
# 1  1.0   4  0.0  NaN  NaN NaN NaN   NaN
# 2  1.0   2  5.0  NaN  NaN NaN NaN   NaN
# 3  1.0   0  2.0  NaN  NaN NaN NaN   NaN
# 4  2.0   2  1.0  NaN  NaN NaN NaN   NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Load Tables from PostgreSQL

# %%
college_df = pd.read_sql("SELECT * FROM collegeplaying", con=engine)
# college_df.head()

# %%
people_df = pd.read_sql("SELECT * FROM people", con=engine)
# people_df.head()

# %%
salaries_df = pd.read_sql("SELECT * FROM salaries", con=engine)
# salaries_df.head()

# %%
salaries_df = salaries_df.groupby('playerid').sum('salary')

# %%
col_sal_df = pd.merge(college_df, salaries_df, how="inner", on='playerid')

# %%
col_sal_peep_df = pd.merge(col_sal_df, people_df, how="inner", on='playerid')

# %%
col_sal_peep_df
# Out:
#        playerid  schoolid  yearid_x  yearid_y     salary  birthyear  \
# 0     aardsda01    pennst      2001     14061  9259750.0     1981.0
# 1     aardsda01      rice      2002     14061  9259750.0     1981.0
# 2     aardsda01      rice      2003     14061  9259750.0     1981.0
# 3      abadan01   gamiddl      1992      2006   327000.0     1972.0
# 4      abadan01   gamiddl      1993      2006   327000.0     1972.0
# ...         ...       ...       ...       ...        ...        ...
# 7423  zupcibo01   oralrob      1987      5976   431000.0     1966.0
# 7424  zuvelpa01  stanford      1977      1989   145000.0     1958.0
# 7425  zuvelpa01  stanford      1978      1989   145000.0     1958.0
# 7426  zuvelpa01  stanford      1979      1989   145000.0     1958.0
# 7427  zuvelpa01  stanford      1980      1989   145000.0     1958.0
#
#       birthmonth  birthday birthcountry birthstate  ... namelast  \
# 0           12.0      27.0          USA         CO  ...  Aardsma
# ...

# %%
col_sal_peep_df = col_sal_peep_df[['playerid', 'schoolid', 'salary', 'namefirst', 'namelast']]

# %%
col_sal_peep_df
# Out:
#        playerid  schoolid     salary namefirst namelast
# 0     aardsda01    pennst  9259750.0     David  Aardsma
# 1     aardsda01      rice  9259750.0     David  Aardsma
# 2     aardsda01      rice  9259750.0     David  Aardsma
# 3      abadan01   gamiddl   327000.0      Andy     Abad
# 4      abadan01   gamiddl   327000.0      Andy     Abad
# ...         ...       ...        ...       ...      ...
# 7423  zupcibo01   oralrob   431000.0       Bob   Zupcic
# 7424  zuvelpa01  stanford   145000.0      Paul  Zuvella
# 7425  zuvelpa01  stanford   145000.0      Paul  Zuvella
# 7426  zuvelpa01  stanford   145000.0      Paul  Zuvella
# 7427  zuvelpa01  stanford   145000.0      Paul  Zuvella
#
# [7428 rows x 5 columns]

# %% [markdown]
# #### Vandy Only With Sort

# %%
vandy = col_sal_peep_df[col_sal_peep_df['schoolid']=='vandy'].drop_duplicates()
vandy = vandy.sort_values('salary', ascending=False)

# %%
vandy
# Out:
#        playerid schoolid      salary namefirst    namelast
# 5332  priceda01    vandy  81851296.0     David       Price
# 105   alvarpe01    vandy  20681704.0     Pedro     Alvarez
# 5342  priorma01    vandy  12800000.0      Mark       Prior
# 5900  sandesc01    vandy  10750000.0     Scott   Sanderson
# 4548  minormi01    vandy   6837500.0      Mike       Minor
# 1357   corajo01    vandy   5622500.0      Joey        Cora
# 2061  flahery01    vandy   4061000.0      Ryan    Flaherty
# 5120   pauljo01    vandy   2640000.0      Josh        Paul
# 377   baxtemi01    vandy   2094418.0      Mike      Baxter
# 2487   grayso01    vandy   1542500.0     Sonny        Gray
# 3841  lewisje01    vandy   1234000.0    Jensen       Lewis
# 3439   katama01    vandy   1060000.0      Matt        Kata
# 1206  chrisni01    vandy    500000.0      Nick  Christiani
# 6256  sowerje01    vandy    384800.0    Jeremy      Sowers
# 4089  madissc01    vandy    135000.0    Scotti     Madison

# %% [markdown]
# ### Fielding

# %%
fielding_df = pd.read_sql("SELECT * FROM fielding", con=engine)
fielding_df
# Out:
#          playerid  yearid  stint teamid lgid pos    g     gs  innouts   po  \
# 0       abercda01    1871      1    TRO   NA  SS    1    NaN      NaN    1
# 1        addybo01    1871      1    RC1   NA  2B   22    NaN      NaN   67
# 2        addybo01    1871      1    RC1   NA  SS    3    NaN      NaN    8
# 3       allisar01    1871      1    CL1   NA  2B    2    NaN      NaN    1
# 4       allisar01    1871      1    CL1   NA  OF   29    NaN      NaN   51
# ...           ...     ...    ...    ...  ...  ..  ...    ...      ...  ...
# 136810  zobribe01    2016      1    CHN   NL  2B  119  113.0   2929.0  177
# 136811  zobribe01    2016      1    CHN   NL  OF   46   29.0    859.0   43
# 136812  zobribe01    2016      1    CHN   NL  SS    1    0.0      6.0    0
# 136813  zuninmi01    2016      1    SEA   AL   C   52   48.0   1331.0  400
# 136814   zychto01    2016      1    SEA   AL   P   12    0.0     41.0    0
#
#             a     e    dp   pb  wp    sb   cs  zr
# ...

# %%
pos_df = fielding_df[['playerid','pos', 'po']]

# %%
pos_df['position'] = pos_df.replace("SS")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/miniconda3/envs/geospatial/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'position'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
bd
# Out:
# re.compile(r'SS', re.UNICODE)
